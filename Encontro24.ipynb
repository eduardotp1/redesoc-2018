# %% [markdown]
# # Balanceamento Estrutural
#
# Importando bibliotecas:

# %%
import networkx as nx
import socnet as sn

from random import choice, random, uniform
from itertools import combinations
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Configurando bibliotecas:

# %%
sn.node_size = 5
sn.node_color = (255, 255, 255)

sn.edge_width = 1

# %% [markdown]
# Definindo constantes:

# %%
NUM_NODES = 15

POSITIVE_COLOR = (0, 0, 255)
NEGATIVE_COLOR = (255, 0, 0)

# %% [markdown]
# Inicialização da simulação:

# %%
def set_edge_color(g, n, m):
    if g.edges[n, m]['signal'] == 1:
        g.edges[n, m]['color'] = POSITIVE_COLOR
    else:
        g.edges[n, m]['color'] = NEGATIVE_COLOR


def build_graph(frac_positives=0):
    g = nx.complete_graph(NUM_NODES)

    sn.reset_node_colors(g)

    for n, m in g.edges:
        if random() < frac_positives:
            g.edges[n, m]['signal'] = 1
        else:
            g.edges[n, m]['signal'] = -1

        set_edge_color(g, n, m)

    sn.reset_positions(g)

    return g

# %% [markdown]
# Passo da simulação:

# %%
def invert(g, n, m):
    g.edges[n, m]['signal'] *= -1

    set_edge_color(g, n, m)


def update(g, mec2_weight=2, mec3_weight=3, mec5_weight=1):
    # Inicializa as pressões.

    for n, m in g.edges():
        g.edges[n, m]['pressure'] = 0

    # Para cada tríade.

    for t in combinations(g.nodes, 3):
        # Lista todas as arestas da tríade.
        edges = [(t[0], t[1]), (t[0], t[2]), (t[1], t[2])]
        triade_weight = 0
        for number in t:
            triade_weight += g.nodes[number]['influence']
            
        triade_weight /= len(t)
        # Conta quantas arestas são positivas.
        num_positives = sum(g.edges[n, m]['signal'] == 1 for n, m in edges)
        # Duas positivas significa tríade instável.
        if num_positives == 2:
            for n, m in edges:
                if g.edges[n, m]['signal'] == -1:
                    g.edges[n, m]['pressure'] += (mec2_weight + triade_weight ) # Mecanismo 2
                else:
                    g.edges[n, m]['pressure'] += (mec3_weight+ triade_weight) # Mecanismo 3

        # Zero positivas também significa tríade instável.
        elif num_positives == 0:
            for n, m in edges:
                g.edges[n, m]['pressure'] += (mec5_weight+triade_weight) # Mecanismo 5

    # Obtém a maior pressão.
    pressure = max(g.edges[n, m]['pressure'] for n, m in g.edges)
    #print(pressure)

    # Se for positiva, inverte uma aresta que esteja
    # sob essa pressão, escolhida aleatoriamente, e
    # devolve True para indicar que houve mudança.
    if pressure > 0:
        n, m = choice([(n, m) for n, m in g.edges if g.edges[n, m]['pressure'] == pressure])
        invert(g, n, m)
        return True

    # Se for zero, devolvendo False para indicar que
    # não houve mudança, ou seja, a rede estabilizou.
    return False

# %%
def set_influences(g):
    for i in g.nodes:
        g.nodes[i]['influence'] = uniform(0, 1)

# %% [markdown]
# Animação da simulação:

# %%
g = build_graph()

set_influences(g)

sn.reset_positions(g)

frames = []

counter = 0
while update(g):
    sn.update_positions(g, weight='signal')
    frames.append(sn.generate_frame(g))
    
    if(counter > 30):
        break
    counter +=1

print('simulação encerrada, gerando animação...')

sn.show_animation(frames)
# Out:
# simulação encerrada, gerando animação...
# <div id="cdf6d2e2-4aa4-46fa-83f0-606bc8980e81" style="height: 526.0px; width: 912.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'cdf6d2e2-4aa4-46fa-83f0-606bc8980e81',
#             [{"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 1.0, null], "y": [0.14547077482291523, 0.33248361646698316, null], "type": "scatter", "uid": "2366b2ac-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.6666134359870024, null], "y": [0.14547077482291523, 0.5375558064770228, null], "type": "scatter", "uid": "2366b2ad-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.046505677290957746, null], "y": [0.14547077482291523, 0.3792156245098856, null], "type": "scatter", "uid": "2366b2ae-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.29759182131001916, null], "y": [0.14547077482291523, 0.6977373007430654, null], "type": "scatter", "uid": "2366b2af-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.9005137477717456, null], "y": [0.14547077482291523, 0.803871193909443, null], "type": "scatter", "uid": "2366b2b0-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.917580557489428, null], "y": [0.14547077482291523, 0.5651163817154153, null], "type": "scatter", "uid": "2366b2b1-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.8128848318562816, null], "y": [0.14547077482291523, 0.16905414226840798, null], "type": "scatter", "uid": "2366b2b2-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.6314806105008146, null], "y": [0.14547077482291523, 0.01019563476569111, null], "type": "scatter", "uid": "2366b2b3-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.37686227060290794, null], "y": [0.14547077482291523, 0.2510375523551043, null], "type": "scatter", "uid": "2366b2b4-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.4394540942259991, null], "y": [0.14547077482291523, 1.0, null], "type": "scatter", "uid": "2366b2b5-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.14942476220607034, null], "y": [0.14547077482291523, 0.8797099367523706, null], "type": "scatter", "uid": "2366b2b6-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.0, null], "y": [0.14547077482291523, 0.6280753998519072, null], "type": "scatter", "uid": "2366b2b7-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.6658207689653476, null], "y": [0.14547077482291523, 0.899755226004065, null], "type": "scatter", "uid": "2366b2b8-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [0.10516525951552029, 0.3565422448040092, null], "y": [0.14547077482291523, 0.0, null], "type": "scatter", "uid": "2366b2b9-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}, "mode": "lines", "x": [1.0, 0.6666134359870024, null], "y": [0.33248361646698316, 0.5375558064770228, null], "type": "scatter", "uid": "2366b2ba-db88-11e8-9456-0028f828353e"}, {"hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}, "mode": "lines", "x": [1.0, 0.046505677290 ...

# %% [markdown]
# Avaliação da simulação:

# %%
def number_components(g):
    h = g.copy()

    for n, m in g.edges:
        if g.edges[n, m]['signal'] == -1:
            h.remove_edge(n, m)

    return nx.number_connected_components(h)


print(number_components(g))
# Out:
# 2
